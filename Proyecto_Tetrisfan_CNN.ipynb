# %% [markdown]
# # Data collection and preprocessing
#
# ---

# %% [markdown]
# ## Installs

# %%
# !pip install noisereduce
# Out:
# Requirement already satisfied: noisereduce in /usr/local/lib/python3.10/dist-packages (2.0.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from noisereduce) (1.10.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from noisereduce) (3.7.1)
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (from noisereduce) (0.10.0.post2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from noisereduce) (1.22.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from noisereduce) (4.65.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa->noisereduce) (3.0.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa->noisereduce) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa->noisereduce) (1.3.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa->noisereduce) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa->noisereduce) (0.56.4)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from librosa->noisereduce) (0.12.1)
# Requirement already satisfied: pooch<1.7,>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa->noisereduce) (1.6.0)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa->noisereduce) (0.3.5)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from librosa->noisereduce) (4.7.1)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa->noisereduce) (0.3)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa->noisereduce) (1.0.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->noisereduce) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->noisereduce) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->noisereduce) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->noisereduce) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->noisereduce) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->noisereduce) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->noisereduce) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->noisereduce) (2.8.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa->noisereduce) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa->noisereduce) (67.7.2)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from pooch<1.7,>=1.0->librosa->noisereduce) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch<1.7,>=1.0->librosa->noisereduce) (2.27.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->noisereduce) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa->noisereduce) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.12.1->librosa->noisereduce) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa->noisereduce) (2.21)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa->noisereduce) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa->noisereduce) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa->noisereduce) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa->noisereduce) (3.4)

# %% [markdown]
# ## Imports

# %%
import io
import os
import glob
from pathlib import Path
import pandas as pd
import numpy as np
import noisereduce as nr
import pickle
import matplotlib.pyplot as plt, IPython.display as ipd
import librosa, librosa.display
import tensorflow as tf
import tensorflow.keras
import tensorflow.keras.layers as LK
import tensorflow.keras.models as MK
from keras.utils import to_categorical
from sklearn.metrics import roc_curve, auc
import gc
from sklearn import metrics
from IPython.display import Javascript, Audio
from google.colab import output
from base64 import b64decode
import warnings
from librosa.util import normalize
from PIL import Image
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Parameters

# %%
fs = 44100           # Sampling rate
top_db = 20          # Silence threshold in decibels

# Mel's spectrogram parameters
n_fft_parameter = int(0.025 * fs)
hop_length_parameter = int(n_fft_parameter/2)
n_mels_parameter = 40

# %% [markdown]
# ## Convert audios to spectrograms

# %%
audioFolders = os.listdir('/content/drive/MyDrive/SEÑALES/Audios Señales')
audioFolders.sort()

for label, rawAudio in enumerate(audioFolders):
  for fileName in glob.glob(os.path.join('/content/drive/MyDrive/SEÑALES/Audios Señales', rawAudio, '*.wav')):
    try:
      signal, sr = librosa.load(fileName, mono=True, sr=fs)
      trimmed_signal = librosa.effects.trim(signal, top_db= 20)
      reduced_noise_signal = nr.reduce_noise(trimmed_signal[0], fs)
      normalized_signal = librosa.util.normalize(reduced_noise_signal)

      plt.specgram(x=normalized_signal, Fs=fs, Fc=0, NFFT=n_fft_parameter, cmap=plt.cm.jet, scale='dB')
      plt.axis('off')
      plt.savefig(f'{fileName[:-3].replace(".","")}.jpg')
      plt.clf
      plt.cla()
      plt.close()

    except Exception as e:
      print(f'Error: {e}')
      continue

print('Images saved correctly')
# Out:
# Images saved correctly

# %% [markdown]
# ## Spectogram reading

# %%
spectogramFolders = os.listdir('/content/drive/MyDrive/SEÑALES/Espectogramas Señales')
spectogramFolders.sort()

dataset = []

for label_spectogram, rawSpectrogram in enumerate(spectogramFolders):
  for fileNameSpecgram in glob.glob(os.path.join('/content/drive/MyDrive/SEÑALES/Espectogramas Señales', rawSpectrogram, '*.jpg')):
    try:

      img = Image.open(fileNameSpecgram)
      box = (80, 58, 576, 427)
      img_crop = img.crop(box)
      img_array = np.asarray(img_crop)
      dataset.append([img_array, label_spectogram])

    except Exception as e:
      print(f'Error: {e}')
      continue

print('Spectogram reading completed')

spectogram= pd.DataFrame(dataset, columns=['SPECTOGRAMS', 'LABEL'])
# Out:
# Spectogram reading completed

# %% [markdown]
# # Dataset
#
# ---

# %%
spectogram.head()
# Out:
#                                          SPECTOGRAMS  LABEL
# 0  [[[62, 231, 228], [62, 231, 228], [62, 231, 22...      0
# 1  [[[8, 92, 208], [8, 92, 208], [8, 92, 208], [8...      0
# 2  [[[33, 134, 216], [33, 134, 216], [33, 134, 21...      0
# 3  [[[118, 238, 164], [118, 238, 164], [118, 238,...      0
# 4  [[[39, 223, 233], [39, 223, 233], [40, 222, 23...      0

# %% [markdown]
# ## Spectograms visualization

# %%
indexes = [5, 145, 270, 410, 545]
labels = ['Empezar', 'Girar', 'Leprechaun', 'Mas', 'Menos']

fig, axs = plt.subplots(1, 5, figsize=(15, 3))

for i, index in enumerate(indexes):
    imageSpectogram = spectogram.loc[index, 'SPECTOGRAMS']
    axs[i].imshow(imageSpectogram)
    axs[i].set_title('Image with label "{}"'.format(labels[i]))

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Partitioning

# %%
x = np.array(spectogram.SPECTOGRAMS.tolist())
y = np.array(spectogram.LABEL.tolist())
y = y.reshape((y.shape[0],-1))

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=10, stratify=y)

print(x.shape)
print(y.shape)
print(x_train.shape, y_train.shape, y_test.shape )
# Out:
# (665, 369, 496, 3)
# (665, 1)
# (532, 369, 496, 3) (532, 1) (133, 1)

# %% [markdown]
# ## Ensuring that they become tensors

# %%
x_train = x_train.reshape((x_train.shape[0], 369, 496, 3))
x_test = x_test.reshape((x_test.shape[0], 369, 496, 3))
print("Training images Size: %s, Label size %s" %(x_train.shape, y_train.shape))
print("Test images size: {0}, Label size: {1}".format(x_test.shape, y_test.shape))
# Out:
# Training images Size: (532, 369, 496, 3), Label size (532, 1)
# Test images size: (133, 369, 496, 3), Label size: (133, 1)

# %% [markdown]
# # CONVOLUTIONAL NEURAL NETWORK BASED ON VGG-19
#
# ---

# %%
#CONVOLUTION

entrada = LK.Input(shape=(369, 496, 3))
conv1 = LK.Conv2D(filters=8, kernel_size=(3,3), padding='same', activation='relu')(entrada)
conv2 = LK.Conv2D(filters=8, kernel_size=(3,3), padding='same', activation='relu')(conv1)
pool1 = LK.MaxPool2D(pool_size=(2,2), strides=(2,2))(conv2)

conv3 = LK.Conv2D(filters=16, kernel_size=(3,3), padding='same', activation='relu')(pool1)
conv4 = LK.Conv2D(filters=16, kernel_size=(3,3), padding='same', activation='relu')(conv3)
pool2 = LK.MaxPool2D(pool_size=(2,2), strides=(2,2))(conv4)

conv5 = LK.Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu')(pool2)
conv6 = LK.Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu')(conv5)
pool3 = LK.MaxPool2D(pool_size=(2,2), strides=(2,2))(conv6)

conv7 = LK.Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu')(pool3)
conv8 = LK.Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu')(conv7)
pool4 = LK.MaxPool2D(pool_size=(2,2), strides=(2,2))(conv8)

conv8 = LK.Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu')(pool4)
conv9 = LK.Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu')(conv8)
pool5 = LK.MaxPool2D(pool_size=(2,2), strides=(2,2))(conv9)

#FLATTEN

flat = LK.Flatten()(pool5)

# NEURONAL NETWORK

fc1 = LK.Dense(units=512, activation='relu', kernel_regularizer= tf.keras.regularizers.L2(0.01))(flat)
drop = LK.Dropout(0.35)(fc1)
fc2 = LK.Dense(units=512, activation='relu', kernel_regularizer= tf.keras.regularizers.L2(0.01))(drop)
drop1 = LK.Dropout(0.4)(fc2)
fc3 = LK.Dense(units=512, activation='relu', kernel_regularizer= tf.keras.regularizers.L2(0.01))(drop1)
drop2 = LK.Dropout(0.35)(fc3)
salida = LK.Dense(units=5, activation='softmax')(drop2)

# %%
#SUMMARY
gonodactylus_simithii = MK.Model(entrada, salida)
gonodactylus_simithii.summary()
# Out:
# Model: "model_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_13 (InputLayer)       [(None, 369, 496, 3)]     0
#
#  conv2d_120 (Conv2D)         (None, 369, 496, 8)       224
#
#  conv2d_121 (Conv2D)         (None, 369, 496, 8)       584
#
#  max_pooling2d_60 (MaxPoolin  (None, 184, 248, 8)      0
#  g2D)
#
#  conv2d_122 (Conv2D)         (None, 184, 248, 16)      1168
#
#  conv2d_123 (Conv2D)         (None, 184, 248, 16)      2320
#
#  max_pooling2d_61 (MaxPoolin  (None, 92, 124, 16)      0
#  g2D)
#
#  conv2d_124 (Conv2D)         (None, 92, 124, 32)       4640
#
#  conv2d_125 (Conv2D)         (None, 92, 124, 32)       9248
#
#  max_pooling2d_62 (MaxPoolin  (None, 46, 62, 32)       0
#  g2D)
#
#  conv2d_126 (Conv2D)         (None, 46, 62, 64)        18496
#
#  conv2d_127 (Conv2D)         (None, 46, 62, 64)        36928
#
#  max_pooling2d_63 (MaxPoolin  (None, 23, 31, 64)       0
#  g2D)
#
#  conv2d_128 (Conv2D)         (None, 23, 31, 128)       73856
#
#  conv2d_129 (Conv2D)         (None, 23, 31, 128)       147584
#
#  max_pooling2d_64 (MaxPoolin  (None, 11, 15, 128)      0
#  g2D)
#
#  flatten_12 (Flatten)        (None, 21120)             0
#
#  dense_48 (Dense)            (None, 512)               10813952
#
#  dropout_36 (Dropout)        (None, 512)               0
#
#  dense_49 (Dense)            (None, 512)               262656
#
#  dropout_37 (Dropout)        (None, 512)               0
#
#  dense_50 (Dense)            (None, 512)               262656
#
#  dropout_38 (Dropout)        (None, 512)               0
#
#  dense_51 (Dense)            (None, 5)                 2565
#
# =================================================================
# Total params: 11,636,877
# Trainable params: 11,636,877
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Clear computer data

# %%
tf.keras.backend.clear_session
gc.collect()
# Out:
# 16046

# %% [markdown]
# ## Training

# %%
#COMPILE MODEL
gonodactylus_simithii.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
filepath = "best_trained_model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=True, mode='max', period=2)

firstTraining = gonodactylus_simithii.fit(x_train, y_train, epochs=150, batch_size=128, validation_data=(x_test, y_test), verbose=1, callbacks=[checkpoint])

gonodactylus_simithii.load_weights(filepath)

loss, acc = gonodactylus_simithii.evaluate(x_test, y_test, verbose=1)
print("The loss is: {0}, and the accuracy is: {1}".format(loss, acc))
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/150
# 5/5 [==============================] - 9s 565ms/step - loss: 20.3381 - accuracy: 0.1598 - val_loss: 16.5208 - val_accuracy: 0.2030
# Epoch 2/150
# 5/5 [==============================] - ETA: 0s - loss: 15.1970 - accuracy: 0.1955
# Epoch 2: val_accuracy improved from -inf to 0.20301, saving model to best_trained_model.h5
# 5/5 [==============================] - 3s 544ms/step - loss: 15.1970 - accuracy: 0.1955 - val_loss: 12.7644 - val_accuracy: 0.2030
# Epoch 3/150
# 5/5 [==============================] - 3s 517ms/step - loss: 11.9114 - accuracy: 0.1974 - val_loss: 10.3630 - val_accuracy: 0.1955
# Epoch 4/150
# 5/5 [==============================] - ETA: 0s - loss: 9.8071 - accuracy: 0.2105
# Epoch 4: val_accuracy improved from 0.20301 to 0.21805, saving model to best_trained_model.h5
# 5/5 [==============================] - 3s 560ms/step - loss: 9.8071 - accuracy: 0.2105 - val_loss: 8.7493 - val_accuracy: 0.2180
# Epoch 5/150
# 5/5 [==============================] - 3s 497ms/step - loss: 8.3231 - accuracy: 0.2406 - val_loss: 7.4770 - val_accuracy: 0.2256
# Epoch 6/150
# 5/5 [==============================] - ETA: 0s - loss: 7.1134 - accuracy: 0.2350
# Epoch 6: val_accuracy improved from 0.21805 to 0.47368, saving model to best_trained_model.h5
# 5/5 [==============================] - 3s 555ms/step - loss: 7.1134 - accuracy: 0.2350 - val_loss: 6.3873 - val_accuracy: 0.4737
# Epoch 7/150
# 5/5 [==============================] - 3s 507ms/step - loss: 6.0557 - accuracy: 0.3477 - val_loss: 5.4292 - val_accuracy: 0.5113
# Epoch 8/150
# 5/5 [==============================] - ETA: 0s - loss: 5.2123 - accuracy: 0.4079
# Epoch 8: val_accuracy improved from 0.47368 to 0.54135, saving model to best_trained_model.h5
# 5/5 [==============================] - 3s 534ms/step - loss: 5.2123 - accuracy: 0.4079 - val_loss: 4.7129 - val_accuracy: 0.5414
# Epoch 9/150
# 5/5 [==============================] - 3s 543ms/step - loss: 4.5868 - accuracy: 0.4267 - val_loss: 4.2680 - val_accuracy: 0.5564
# Epoch 10/150
# 5/5 [==============================] - ETA: 0s - loss: 4.0665 - accuracy: 0.5150
# Epoch 10: val_accuracy did not improve from 0.54135
# 5/5 [==============================] - 3s 558ms/step - loss: 4.0665 - accuracy: 0.5150 - val_loss: 3.7850 - val_accuracy: 0.4737
# Epoch 11/150
# 5/5 [==============================] - 3s 541ms/step - loss: 3.6514 - accuracy: 0.5169 - val_loss: 3.5074 - val_accuracy: 0.4962
# Epoch 12/150
# 5/5 [==============================] - ETA: 0s - loss: 3.3748 - accuracy: 0.5545
# Epoch 12: val_accuracy improved from 0.54135 to 0.63910, saving model to best_trained_model.h5
# 5/5 [==============================] - 3s 524ms/step - loss: 3.3748 - accuracy: 0.5545 - val_loss: 3.1153 - val_accuracy: 0.6391
# Epoch 13/150
# 5/5 [==============================] - 3s 499ms/step - loss: 2.9200 - accuracy: 0.6786 - val_loss: 2.9485 - val_accuracy: 0.6692
# Epoch 14/150
# 5/5 [==============================] - ETA: 0s - loss: 2.7272 - accuracy: 0.6673
# Epoch 14: val_accuracy improved from 0.63910 to 0.66917, saving model to best_trained_model.h5
# 5/5 [==============================] - 3s 528ms/step - loss: 2.7272 - accuracy: 0.6673 - val_loss: 2.5213 - val_accuracy: 0.6692
# Epoch 15/150
# 5/5 [==============================] - 3s 532ms/step - loss: 2.3716 - accuracy: 0.7575 - val_loss: 2.4005 - val_accuracy: 0.6992
# Epoch 16/150
# 5/5 [==============================] - ETA: 0s - loss: 2.2149 - accuracy: 0.7500
# Epoch 16: val_accuracy improved from 0.66917 to 0.75940, saving model to best_trained_model.h5
# 5/5 [==============================] - 3s 516ms/step - loss: 2.2149 - accuracy: 0.7500 - val_loss: 2.1583 - val_accuracy: 0.7594
# Epoch 17/150
# 5/5 [==============================] - 3s 516ms/step - loss: 2.0755 - accuracy: 0.7932 - val_loss: 2.1576 - val_accuracy: 0.7594
# Epoch 18/150
# 5/5 [==============================] - ETA: 0s - loss: 1.9517 - accuracy: 0.8083
# Epoch 18: val_accuracy did not improve from 0.75940
# 5/5 [==============================] - 3s 513ms/step - loss: 1.9517 - accuracy: 0.8083 - val_loss: 2.1546 - val_accuracy: 0.7444
# Epoch 19/150
# 5/5 [==============================] - 2s 476ms/step - loss: 1.9079 - accuracy: 0.7951 - val_loss: 1.8835 - val_accuracy: 0.7744
# Epoch 20/150
# 5/5 [==============================] - ETA: 0s - loss: 1.7095 - accuracy: 0.8571
# Epoch 20: val_accuracy improved from 0.75940 to 0.80451, saving model to best_trained_model.h5
# 5/5 [==============================] - 3s 523ms/step - loss: 1.7095 - accuracy: 0.8571 - val_loss: 1.8894 - val_accuracy: 0.8045
# Epoch 21/150
# 5/5 [==============================] - 2s 479ms/step - loss: 1.5522 - accuracy: 0.8929 - val_loss: 1.8504 - val_accuracy: 0.8045
# Epoch 22/150
# 5/5 [==============================] - ETA: 0s - loss: 1.4867 - accuracy: 0.8947
# Epoch 22: val_accuracy did not improve from 0.80451
# 5/5 [==============================] - 2s 475ms/step - loss: 1.4867 - accuracy: 0.8947 - val_loss: 1.9863 - val_accuracy: 0.7744
# Epoch 23/150
# 5/5 [==============================] - 2s 471ms/step - loss: 1.5223 - accuracy: 0.8891 - val_loss: 1.6551 - val_accuracy: 0.8496
# Epoch 24/150
# 5/5 [==============================] - ETA: 0s - loss: 1.4622 - accuracy: 0.9041
# Epoch 24: val_accuracy improved from 0.80451 to 0.82707, saving model to best_trained_model.h5
# 5/5 [==============================] - 3s 502ms/step - loss: 1.4622 - accuracy: 0.9041 - val_loss: 1.6845 - val_accuracy: 0.8271
# Epoch 25/150
# 5/5 [==============================] - 3s 507ms/step - loss: 1.2962 - accuracy: 0.9474 - val_loss: 1.7935 - val_accuracy: 0.7970
# Epoch 26/150
# 5/5 [==============================] - ETA: 0s - loss: 1.2080 - accuracy: 0.9586
# Epoch 26: val_accuracy improved from 0.82707 to 0.86466, saving model to best_trained_model.h5
# 5/5 [==============================] - 3s 547ms/step - loss: 1.2080 - accuracy: 0.9586 - val_loss: 1.5623 - val_accuracy: 0.8647
# Epoch 27/150
# 5/5 [==============================] - 2s 468ms/step - loss: 1.0970 - accuracy: 0.9793 - val_loss: 1.5668 - val_accuracy: 0.8647
# Epoch 28/150
# 5/5 [==============================] - ETA: 0s - loss: 1.1173 - accuracy: 0.9699
# Epoch 28: val_accuracy did not improve from 0.86466
# 5/5 [==============================] - 2s 468ms/step - loss: 1.1173 - accuracy: 0.9699 - val_loss: 1.4765 - val_accuracy: 0.8571
# Epoch 29/150
# 5/5 [==============================] - 3s 498ms/step - loss: 1.0453 - accuracy: 0.9624 - val_loss: 1.3529 - val_accuracy: 0.8647
# Epoch 30/150
# 5/5 [==============================] - ETA: 0s - loss: 1.0320 - accuracy: 0.9568
# Epoch 30: val_accuracy improved from 0.86466 to 0.87218, saving model to best_trained_model.h5
# 5/5 [==============================] - 3s 527ms/step - loss: 1.0320 - accuracy: 0.9568 - val_loss: 1.3182 - val_accuracy: 0.8722
# Epoch 31/150
# 5/5 [==============================] - 3s 507ms/step - loss: 0.9809 - accuracy: 0.9605 - val_loss: 1.3791 - val_accuracy: 0.8571
# Epoch 32/150
# 5/5 [==============================] - ETA: 0s - loss: 0.9086 - accuracy: 0.9756
# Epoch 32: val_accuracy did not improve from 0.87218
# 5/5 [==============================] - 3s 507ms/step - loss: 0.9086 - accuracy: 0.9756 - val_loss: 1.3486 - val_accuracy: 0.8571
# Epoch 33/150
# 5/5 [==============================] - 2s 466ms/step - loss: 0.8660 - accuracy: 0.9793 - val_loss: 1.3820 - val_accuracy: 0.8496
# Epoch 34/150
# 5/5 [==============================] - ETA: 0s - loss: 0.8276 - accuracy: 0.9793
# Epoch 34: val_accuracy improved from 0.87218 to 0.89474, saving model to best_trained_model.h5
# 5/5 [==============================] - 3s 497ms/step - loss: 0.8276 - accuracy: 0.9793 - val_loss: 1.2713 - val_accuracy: 0.8947
# Epoch 35/150
# 5/5 [==============================] - 3s 499ms/step - loss: 0.8236 - accuracy: 0.9718 - val_loss: 1.1209 - val_accuracy: 0.8722
# Epoch 36/150
# 5/5 [==============================] - ETA: 0s - loss: 0.7798 - accuracy: 0.9718
# Epoch 36: val_accuracy did not improve from 0.89474
# 5/5 [==============================] - 2s 479ms/step - loss: 0.7798 - accuracy: 0.9718 - val_loss: 1.1576 - val_accuracy: 0.8797
# Epoch 37/150
# 5/5 [==============================] - 3s 489ms/step - loss: 0.7747 - accuracy: 0.9699 - val_loss: 1.0954 - val_accuracy: 0.8647
# Epoch 38/150
# 5/5 [==============================] - ETA: 0s - loss: 0.7654 - accuracy: 0.9737
# Epoch 38: val_accuracy did not improve from 0.89474
# 5/5 [==============================] - 3s 506ms/step - loss: 0.7654 - accuracy: 0.9737 - val_loss: 1.1573 - val_accuracy: 0.8496
# Epoch 39/150
# 5/5 [==============================] - 2s 472ms/step - loss: 0.6943 - accuracy: 0.9944 - val_loss: 1.2748 - val_accuracy: 0.8571
# Epoch 40/150
# 5/5 [==============================] - ETA: 0s - loss: 0.7304 - accuracy: 0.9718
# Epoch 40: val_accuracy did not improve from 0.89474
# 5/5 [==============================] - 3s 509ms/step - loss: 0.7304 - accuracy: 0.9718 - val_loss: 1.2838 - val_accuracy: 0.8496
# Epoch 41/150
# 5/5 [==============================] - 3s 506ms/step - loss: 0.7575 - accuracy: 0.9680 - val_loss: 1.1589 - val_accuracy: 0.8271
# Epoch 42/150
# 5/5 [==============================] - ETA: 0s - loss: 0.7531 - accuracy: 0.9680
# Epoch 42: val_accuracy did not improve from 0.89474
# 5/5 [==============================] - 2s 488ms/step - loss: 0.7531 - accuracy: 0.9680 - val_loss: 1.2279 - val_accuracy: 0.8271
# Epoch 43/150
# 5/5 [==============================] - 3s 512ms/step - loss: 0.7083 - accuracy: 0.9737 - val_loss: 1.1895 - val_accuracy: 0.8496
# Epoch 44/150
# 5/5 [==============================] - ETA: 0s - loss: 0.7088 - accuracy: 0.9680
# Epoch 44: val_accuracy did not improve from 0.89474
# 5/5 [==============================] - 3s 509ms/step - loss: 0.7088 - accuracy: 0.9680 - val_loss: 1.4823 - val_accuracy: 0.8496
# Epoch 45/150
# 5/5 [==============================] - 3s 513ms/step - loss: 0.6803 - accuracy: 0.9737 - val_loss: 1.1845 - val_accuracy: 0.8947
# Epoch 46/150
# 5/5 [==============================] - ETA: 0s - loss: 0.6503 - accuracy: 0.9812
# Epoch 46: val_accuracy did not improve from 0.89474
# 5/5 [==============================] - 2s 476ms/step - loss: 0.6503 - accuracy: 0.9812 - val_loss: 1.1085 - val_accuracy: 0.8947
# Epoch 47/150
# 5/5 [==============================] - 3s 521ms/step - loss: 0.6282 - accuracy: 0.9887 - val_loss: 1.2854 - val_accuracy: 0.8571
# Epoch 48/150
# 5/5 [==============================] - ETA: 0s - loss: 0.6304 - accuracy: 0.9906
# Epoch 48: val_accuracy did not improve from 0.89474
# 5/5 [==============================] - 3s 500ms/step - loss: 0.6304 - accuracy: 0.9906 - val_loss: 1.1783 - val_accuracy: 0.8571
# Epoch 49/150
# 5/5 [==============================] - 3s 512ms/step - loss: 0.6240 - accuracy: 0.9850 - val_loss: 1.0038 - val_accuracy: 0.8797
# Epoch 50/150
# 5/5 [==============================] - ETA: 0s - loss: 0.5736 - accuracy: 0.9925
# Epoch 50: val_accuracy did not improve from 0.89474
# 5/5 [==============================] - 3s 511ms/step - loss: 0.5736 - accuracy: 0.9925 - val_loss: 0.9835 - val_accuracy: 0.8722
# Epoch 51/150
# 5/5 [==============================] - 3s 511ms/step - loss: 0.5589 - accuracy: 0.9906 - val_loss: 0.9787 - val_accuracy: 0.8797
# Epoch 52/150
# 5/5 [==============================] - ETA: 0s - loss: 0.5188 - accuracy: 0.9944
# Epoch 52: val_accuracy did not improve from 0.89474
# 5/5 [==============================] - 2s 491ms/step - loss: 0.5188 - accuracy: 0.9944 - val_loss: 0.9948 - val_accuracy: 0.8797
# Epoch 53/150
# 5/5 [==============================] - 3s 524ms/step - loss: 0.4905 - accuracy: 0.9962 - val_loss: 0.9806 - val_accuracy: 0.9023
# Epoch 54/150
# 5/5 [==============================] - ETA: 0s - loss: 0.5308 - accuracy: 0.9812
# Epoch 54: val_accuracy did not improve from 0.89474
# 5/5 [==============================] - 3s 512ms/step - loss: 0.5308 - accuracy: 0.9812 - val_loss: 0.9621 - val_accuracy: 0.8647
# Epoch 55/150
# 5/5 [==============================] - 3s 508ms/step - loss: 0.4917 - accuracy: 0.9850 - val_loss: 0.8464 - val_accuracy: 0.9023
# Epoch 56/150
# 5/5 [==============================] - ETA: 0s - loss: 0.4753 - accuracy: 0.9925
# Epoch 56: val_accuracy did not improve from 0.89474
# 5/5 [==============================] - 3s 516ms/step - loss: 0.4753 - accuracy: 0.9925 - val_loss: 0.8830 - val_accuracy: 0.8722
# Epoch 57/150
# 5/5 [==============================] - 3s 515ms/step - loss: 0.4516 - accuracy: 0.9944 - val_loss: 1.0301 - val_accuracy: 0.8421
# Epoch 58/150
# 5/5 [==============================] - ETA: 0s - loss: 0.4486 - accuracy: 0.9944
# Epoch 58: val_accuracy did not improve from 0.89474
# 5/5 [==============================] - 3s 518ms/step - loss: 0.4486 - accuracy: 0.9944 - val_loss: 1.0830 - val_accuracy: 0.8947
# Epoch 59/150
# 5/5 [==============================] - 3s 515ms/step - loss: 0.4394 - accuracy: 0.9906 - val_loss: 0.9572 - val_accuracy: 0.8647
# Epoch 60/150
# 5/5 [==============================] - ETA: 0s - loss: 0.4243 - accuracy: 0.9868
# Epoch 60: val_accuracy improved from 0.89474 to 0.90226, saving model to best_trained_model.h5
# 5/5 [==============================] - 3s 512ms/step - loss: 0.4243 - accuracy: 0.9868 - val_loss: 0.8739 - val_accuracy: 0.9023
# Epoch 61/150
# 5/5 [==============================] - 2s 476ms/step - loss: 0.5033 - accuracy: 0.9624 - val_loss: 1.1345 - val_accuracy: 0.8421
# Epoch 62/150
# 5/5 [==============================] - ETA: 0s - loss: 0.5053 - accuracy: 0.9586
# Epoch 62: val_accuracy improved from 0.90226 to 0.90977, saving model to best_trained_model.h5
# 5/5 [==============================] - 3s 544ms/step - loss: 0.5053 - accuracy: 0.9586 - val_loss: 0.6763 - val_accuracy: 0.9098
# Epoch 63/150
# 5/5 [==============================] - 3s 515ms/step - loss: 0.4987 - accuracy: 0.9605 - val_loss: 0.7391 - val_accuracy: 0.8947
# Epoch 64/150
# 5/5 [==============================] - ETA: 0s - loss: 0.4697 - accuracy: 0.9850
# Epoch 64: val_accuracy did not improve from 0.90977
# 5/5 [==============================] - 3s 522ms/step - loss: 0.4697 - accuracy: 0.9850 - val_loss: 0.7404 - val_accuracy: 0.8722
# Epoch 65/150
# 5/5 [==============================] - 3s 503ms/step - loss: 0.4155 - accuracy: 0.9962 - val_loss: 0.7650 - val_accuracy: 0.8947
# Epoch 66/150
# 5/5 [==============================] - ETA: 0s - loss: 0.4151 - accuracy: 0.9925
# Epoch 66: val_accuracy did not improve from 0.90977
# 5/5 [==============================] - 3s 506ms/step - loss: 0.4151 - accuracy: 0.9925 - val_loss: 0.8461 - val_accuracy: 0.8947
# Epoch 67/150
# 5/5 [==============================] - 3s 510ms/step - loss: 0.4025 - accuracy: 0.9944 - val_loss: 0.7843 - val_accuracy: 0.8797
# Epoch 68/150
# 5/5 [==============================] - ETA: 0s - loss: 0.3896 - accuracy: 0.9962
# Epoch 68: val_accuracy did not improve from 0.90977
# 5/5 [==============================] - 3s 501ms/step - loss: 0.3896 - accuracy: 0.9962 - val_loss: 0.7370 - val_accuracy: 0.9098
# Epoch 69/150
# 5/5 [==============================] - 3s 514ms/step - loss: 0.3874 - accuracy: 0.9906 - val_loss: 0.7655 - val_accuracy: 0.8872
# Epoch 70/150
# 5/5 [==============================] - ETA: 0s - loss: 0.3732 - accuracy: 0.9887
# Epoch 70: val_accuracy did not improve from 0.90977
# 5/5 [==============================] - 3s 504ms/step - loss: 0.3732 - accuracy: 0.9887 - val_loss: 0.6263 - val_accuracy: 0.9023
# Epoch 71/150
# 5/5 [==============================] - 2s 471ms/step - loss: 0.3966 - accuracy: 0.9737 - val_loss: 0.8082 - val_accuracy: 0.9023
# Epoch 72/150
# 5/5 [==============================] - ETA: 0s - loss: 0.4170 - accuracy: 0.9812
# Epoch 72: val_accuracy did not improve from 0.90977
# 5/5 [==============================] - 2s 473ms/step - loss: 0.4170 - accuracy: 0.9812 - val_loss: 0.8731 - val_accuracy: 0.8722
# Epoch 73/150
# 5/5 [==============================] - 3s 504ms/step - loss: 0.4070 - accuracy: 0.9812 - val_loss: 0.7458 - val_accuracy: 0.8947
# Epoch 74/150
# 5/5 [==============================] - ETA: 0s - loss: 0.3885 - accuracy: 0.9887
# Epoch 74: val_accuracy did not improve from 0.90977
# 5/5 [==============================] - 3s 511ms/step - loss: 0.3885 - accuracy: 0.9887 - val_loss: 0.9891 - val_accuracy: 0.8797
# Epoch 75/150
# 5/5 [==============================] - 3s 511ms/step - loss: 0.4095 - accuracy: 0.9868 - val_loss: 0.9832 - val_accuracy: 0.8872
# Epoch 76/150
# 5/5 [==============================] - ETA: 0s - loss: 0.3826 - accuracy: 0.9925
# Epoch 76: val_accuracy improved from 0.90977 to 0.91729, saving model to best_trained_model.h5
# 5/5 [==============================] - 3s 502ms/step - loss: 0.3826 - accuracy: 0.9925 - val_loss: 0.8876 - val_accuracy: 0.9173
# Epoch 77/150
# 5/5 [==============================] - 2s 472ms/step - loss: 0.3857 - accuracy: 0.9906 - val_loss: 0.7576 - val_accuracy: 0.8947
# Epoch 78/150
# 5/5 [==============================] - ETA: 0s - loss: 0.4130 - accuracy: 0.9793
# Epoch 78: val_accuracy did not improve from 0.91729
# 5/5 [==============================] - 3s 506ms/step - loss: 0.4130 - accuracy: 0.9793 - val_loss: 0.7975 - val_accuracy: 0.8647
# Epoch 79/150
# 5/5 [==============================] - 3s 508ms/step - loss: 0.5156 - accuracy: 0.9511 - val_loss: 0.8853 - val_accuracy: 0.8421
# Epoch 80/150
# 5/5 [==============================] - ETA: 0s - loss: 0.5666 - accuracy: 0.9323
# Epoch 80: val_accuracy did not improve from 0.91729
# 5/5 [==============================] - 3s 494ms/step - loss: 0.5666 - accuracy: 0.9323 - val_loss: 0.7394 - val_accuracy: 0.8797
# Epoch 81/150
# 5/5 [==============================] - 3s 509ms/step - loss: 0.4590 - accuracy: 0.9887 - val_loss: 0.8578 - val_accuracy: 0.8947
# Epoch 82/150
# 5/5 [==============================] - ETA: 0s - loss: 0.4472 - accuracy: 0.9962
# Epoch 82: val_accuracy did not improve from 0.91729
# 5/5 [==============================] - 2s 474ms/step - loss: 0.4472 - accuracy: 0.9962 - val_loss: 1.0573 - val_accuracy: 0.8872
# Epoch 83/150
# 5/5 [==============================] - 3s 507ms/step - loss: 0.4474 - accuracy: 0.9962 - val_loss: 1.3593 - val_accuracy: 0.8647
# Epoch 84/150
# 5/5 [==============================] - ETA: 0s - loss: 0.4640 - accuracy: 0.9887
# Epoch 84: val_accuracy did not improve from 0.91729
# 5/5 [==============================] - 2s 476ms/step - loss: 0.4640 - accuracy: 0.9887 - val_loss: 1.4430 - val_accuracy: 0.8571
# Epoch 85/150
# 5/5 [==============================] - 3s 523ms/step - loss: 0.4829 - accuracy: 0.9868 - val_loss: 0.8396 - val_accuracy: 0.9023
# Epoch 86/150
# 5/5 [==============================] - ETA: 0s - loss: 0.4376 - accuracy: 0.9906
# Epoch 86: val_accuracy did not improve from 0.91729
# 5/5 [==============================] - 2s 481ms/step - loss: 0.4376 - accuracy: 0.9906 - val_loss: 0.8055 - val_accuracy: 0.8797
# Epoch 87/150
# 5/5 [==============================] - 3s 509ms/step - loss: 0.4797 - accuracy: 0.9812 - val_loss: 0.8613 - val_accuracy: 0.8647
# Epoch 88/150
# 5/5 [==============================] - ETA: 0s - loss: 0.4510 - accuracy: 0.9850
# Epoch 88: val_accuracy did not improve from 0.91729
# 5/5 [==============================] - 2s 472ms/step - loss: 0.4510 - accuracy: 0.9850 - val_loss: 0.9524 - val_accuracy: 0.8872
# Epoch 89/150
# 5/5 [==============================] - 2s 476ms/step - loss: 0.4410 - accuracy: 0.9812 - val_loss: 0.8719 - val_accuracy: 0.8571
# Epoch 90/150
# 5/5 [==============================] - ETA: 0s - loss: 0.3959 - accuracy: 0.9962
# Epoch 90: val_accuracy did not improve from 0.91729
# 5/5 [==============================] - 3s 513ms/step - loss: 0.3959 - accuracy: 0.9962 - val_loss: 1.0466 - val_accuracy: 0.8195
# Epoch 91/150
# 5/5 [==============================] - 3s 498ms/step - loss: 0.4067 - accuracy: 0.9887 - val_loss: 0.9250 - val_accuracy: 0.8872
# Epoch 92/150
# 5/5 [==============================] - ETA: 0s - loss: 0.3833 - accuracy: 0.9925
# Epoch 92: val_accuracy did not improve from 0.91729
# 5/5 [==============================] - 3s 508ms/step - loss: 0.3833 - accuracy: 0.9925 - val_loss: 0.7862 - val_accuracy: 0.8872
# Epoch 93/150
# 5/5 [==============================] - 3s 502ms/step - loss: 0.3686 - accuracy: 0.9944 - val_loss: 0.7461 - val_accuracy: 0.8872
# Epoch 94/150
# 5/5 [==============================] - ETA: 0s - loss: 0.3586 - accuracy: 0.9925
# Epoch 94: val_accuracy did not improve from 0.91729
# 5/5 [==============================] - 2s 473ms/step - loss: 0.3586 - accuracy: 0.9925 - val_loss: 0.6947 - val_accuracy: 0.9023
# Epoch 95/150
# 5/5 [==============================] - 3s 509ms/step - loss: 0.3432 - accuracy: 0.9925 - val_loss: 0.5978 - val_accuracy: 0.9323
# Epoch 96/150
# 5/5 [==============================] - ETA: 0s - loss: 0.3318 - accuracy: 0.9925
# Epoch 96: val_accuracy did not improve from 0.91729
# 5/5 [==============================] - 3s 520ms/step - loss: 0.3318 - accuracy: 0.9925 - val_loss: 0.6612 - val_accuracy: 0.8872
# Epoch 97/150
# 5/5 [==============================] - 2s 481ms/step - loss: 0.3173 - accuracy: 0.9944 - val_loss: 0.7634 - val_accuracy: 0.8947
# Epoch 98/150
# 5/5 [==============================] - ETA: 0s - loss: 0.3116 - accuracy: 0.9944
# Epoch 98: val_accuracy did not improve from 0.91729
# 5/5 [==============================] - 3s 507ms/step - loss: 0.3116 - accuracy: 0.9944 - val_loss: 0.8614 - val_accuracy: 0.8872
# Epoch 99/150
# 5/5 [==============================] - 2s 479ms/step - loss: 0.3135 - accuracy: 0.9906 - val_loss: 0.7311 - val_accuracy: 0.9173
# Epoch 100/150
# 5/5 [==============================] - ETA: 0s - loss: 0.2915 - accuracy: 0.9962
# Epoch 100: val_accuracy did not improve from 0.91729
# 5/5 [==============================] - 3s 511ms/step - loss: 0.2915 - accuracy: 0.9962 - val_loss: 0.8489 - val_accuracy: 0.9098
# Epoch 101/150
# 5/5 [==============================] - 3s 513ms/step - loss: 0.3019 - accuracy: 0.9925 - val_loss: 0.7844 - val_accuracy: 0.8722
# Epoch 102/150
# 5/5 [==============================] - ETA: 0s - loss: 0.3108 - accuracy: 0.9887
# Epoch 102: val_accuracy did not improve from 0.91729
# 5/5 [==============================] - 3s 493ms/step - loss: 0.3108 - accuracy: 0.9887 - val_loss: 0.9137 - val_accuracy: 0.8496
# Epoch 103/150
# 5/5 [==============================] - 3s 507ms/step - loss: 0.3459 - accuracy: 0.9887 - val_loss: 0.6428 - val_accuracy: 0.8947
# Epoch 104/150
# 5/5 [==============================] - ETA: 0s - loss: 0.3269 - accuracy: 0.9962
# Epoch 104: val_accuracy did not improve from 0.91729
# 5/5 [==============================] - 2s 473ms/step - loss: 0.3269 - accuracy: 0.9962 - val_loss: 0.5661 - val_accuracy: 0.9023
# Epoch 105/150
# 5/5 [==============================] - 2s 474ms/step - loss: 0.3440 - accuracy: 0.9925 - val_loss: 0.5161 - val_accuracy: 0.9173
# Epoch 106/150
# 5/5 [==============================] - ETA: 0s - loss: 0.3300 - accuracy: 0.9944
# Epoch 106: val_accuracy did not improve from 0.91729
# 5/5 [==============================] - 2s 478ms/step - loss: 0.3300 - accuracy: 0.9944 - val_loss: 0.6540 - val_accuracy: 0.8797
# Epoch 107/150
# 5/5 [==============================] - 3s 523ms/step - loss: 0.3200 - accuracy: 0.9925 - val_loss: 0.6637 - val_accuracy: 0.8947
# Epoch 108/150
# 5/5 [==============================] - ETA: 0s - loss: 0.3313 - accuracy: 0.9906
# Epoch 108: val_accuracy improved from 0.91729 to 0.92481, saving model to best_trained_model.h5
# 5/5 [==============================] - 3s 554ms/step - loss: 0.3313 - accuracy: 0.9906 - val_loss: 0.6144 - val_accuracy: 0.9248
# Epoch 109/150
# 5/5 [==============================] - 2s 475ms/step - loss: 0.3147 - accuracy: 0.9906 - val_loss: 0.7674 - val_accuracy: 0.8797
# Epoch 110/150
# 5/5 [==============================] - ETA: 0s - loss: 0.3119 - accuracy: 0.9925
# Epoch 110: val_accuracy did not improve from 0.92481
# 5/5 [==============================] - 3s 510ms/step - loss: 0.3119 - accuracy: 0.9925 - val_loss: 0.9084 - val_accuracy: 0.8571
# Epoch 111/150
# 5/5 [==============================] - 2s 477ms/step - loss: 0.3191 - accuracy: 0.9831 - val_loss: 0.7482 - val_accuracy: 0.9023
# Epoch 112/150
# 5/5 [==============================] - ETA: 0s - loss: 0.3548 - accuracy: 0.9850
# Epoch 112: val_accuracy did not improve from 0.92481
# 5/5 [==============================] - 3s 518ms/step - loss: 0.3548 - accuracy: 0.9850 - val_loss: 0.7219 - val_accuracy: 0.8722
# Epoch 113/150
# 5/5 [==============================] - 3s 498ms/step - loss: 0.4010 - accuracy: 0.9756 - val_loss: 0.7369 - val_accuracy: 0.8872
# Epoch 114/150
# 5/5 [==============================] - ETA: 0s - loss: 0.4870 - accuracy: 0.9492
# Epoch 114: val_accuracy did not improve from 0.92481
# 5/5 [==============================] - 3s 511ms/step - loss: 0.4870 - accuracy: 0.9492 - val_loss: 0.8192 - val_accuracy: 0.8722
# Epoch 115/150
# 5/5 [==============================] - 3s 511ms/step - loss: 0.4365 - accuracy: 0.9699 - val_loss: 0.9684 - val_accuracy: 0.8571
# Epoch 116/150
# 5/5 [==============================] - ETA: 0s - loss: 0.3946 - accuracy: 0.9906
# Epoch 116: val_accuracy did not improve from 0.92481
# 5/5 [==============================] - 2s 482ms/step - loss: 0.3946 - accuracy: 0.9906 - val_loss: 1.0869 - val_accuracy: 0.8571
# Epoch 117/150
# 5/5 [==============================] - 3s 508ms/step - loss: 0.4454 - accuracy: 0.9887 - val_loss: 1.0573 - val_accuracy: 0.8797
# Epoch 118/150
# 5/5 [==============================] - ETA: 0s - loss: 0.4289 - accuracy: 0.9887
# Epoch 118: val_accuracy did not improve from 0.92481
# 5/5 [==============================] - 3s 519ms/step - loss: 0.4289 - accuracy: 0.9887 - val_loss: 0.8246 - val_accuracy: 0.8797
# Epoch 119/150
# 5/5 [==============================] - 2s 480ms/step - loss: 0.4523 - accuracy: 0.9868 - val_loss: 0.7364 - val_accuracy: 0.8797
# Epoch 120/150
# 5/5 [==============================] - ETA: 0s - loss: 0.4299 - accuracy: 0.9906
# Epoch 120: val_accuracy did not improve from 0.92481
# 5/5 [==============================] - 2s 476ms/step - loss: 0.4299 - accuracy: 0.9906 - val_loss: 0.7492 - val_accuracy: 0.9023
# Epoch 121/150
# 5/5 [==============================] - 3s 511ms/step - loss: 0.4052 - accuracy: 1.0000 - val_loss: 0.8188 - val_accuracy: 0.9323
# Epoch 122/150
# 5/5 [==============================] - ETA: 0s - loss: 0.4203 - accuracy: 0.9906
# Epoch 122: val_accuracy did not improve from 0.92481
# 5/5 [==============================] - 3s 508ms/step - loss: 0.4203 - accuracy: 0.9906 - val_loss: 0.6596 - val_accuracy: 0.9248
# Epoch 123/150
# 5/5 [==============================] - 2s 482ms/step - loss: 0.3872 - accuracy: 0.9962 - val_loss: 0.6072 - val_accuracy: 0.9248
# Epoch 124/150
# 5/5 [==============================] - ETA: 0s - loss: 0.4048 - accuracy: 0.9887
# Epoch 124: val_accuracy improved from 0.92481 to 0.94737, saving model to best_trained_model.h5
# 5/5 [==============================] - 3s 552ms/step - loss: 0.4048 - accuracy: 0.9887 - val_loss: 0.5157 - val_accuracy: 0.9474
# Epoch 125/150
# 5/5 [==============================] - 2s 476ms/step - loss: 0.3691 - accuracy: 0.9981 - val_loss: 0.5629 - val_accuracy: 0.9474
# Epoch 126/150
# 5/5 [==============================] - ETA: 0s - loss: 0.3701 - accuracy: 0.9962
# Epoch 126: val_accuracy improved from 0.94737 to 0.95489, saving model to best_trained_model.h5
# 5/5 [==============================] - 3s 529ms/step - loss: 0.3701 - accuracy: 0.9962 - val_loss: 0.5900 - val_accuracy: 0.9549
# Epoch 127/150
# 5/5 [==============================] - 3s 493ms/step - loss: 0.3408 - accuracy: 0.9981 - val_loss: 0.6148 - val_accuracy: 0.9549
# Epoch 128/150
# 5/5 [==============================] - ETA: 0s - loss: 0.3226 - accuracy: 0.9981
# Epoch 128: val_accuracy did not improve from 0.95489
# 5/5 [==============================] - 3s 517ms/step - loss: 0.3226 - accuracy: 0.9981 - val_loss: 0.6026 - val_accuracy: 0.9398
# Epoch 129/150
# 5/5 [==============================] - 3s 494ms/step - loss: 0.3004 - accuracy: 1.0000 - val_loss: 0.6049 - val_accuracy: 0.9323
# Epoch 130/150
# 5/5 [==============================] - ETA: 0s - loss: 0.2862 - accuracy: 0.9981
# Epoch 130: val_accuracy did not improve from 0.95489
# 5/5 [==============================] - 2s 483ms/step - loss: 0.2862 - accuracy: 0.9981 - val_loss: 0.6292 - val_accuracy: 0.9323
# Epoch 131/150
# 5/5 [==============================] - 3s 510ms/step - loss: 0.2817 - accuracy: 0.9962 - val_loss: 0.6005 - val_accuracy: 0.9323
# Epoch 132/150
# 5/5 [==============================] - ETA: 0s - loss: 0.2613 - accuracy: 0.9981
# Epoch 132: val_accuracy did not improve from 0.95489
# 5/5 [==============================] - 3s 509ms/step - loss: 0.2613 - accuracy: 0.9981 - val_loss: 0.5515 - val_accuracy: 0.9173
# Epoch 133/150
# 5/5 [==============================] - 2s 478ms/step - loss: 0.2597 - accuracy: 0.9962 - val_loss: 0.5657 - val_accuracy: 0.9173
# Epoch 134/150
# 5/5 [==============================] - ETA: 0s - loss: 0.2496 - accuracy: 0.9981
# Epoch 134: val_accuracy did not improve from 0.95489
# 5/5 [==============================] - 3s 523ms/step - loss: 0.2496 - accuracy: 0.9981 - val_loss: 0.5583 - val_accuracy: 0.9098
# Epoch 135/150
# 5/5 [==============================] - 3s 515ms/step - loss: 0.2583 - accuracy: 0.9925 - val_loss: 0.5539 - val_accuracy: 0.9248
# Epoch 136/150
# 5/5 [==============================] - ETA: 0s - loss: 0.2387 - accuracy: 0.9981
# Epoch 136: val_accuracy did not improve from 0.95489
# 5/5 [==============================] - 3s 513ms/step - loss: 0.2387 - accuracy: 0.9981 - val_loss: 0.6080 - val_accuracy: 0.9173
# Epoch 137/150
# 5/5 [==============================] - 2s 476ms/step - loss: 0.2419 - accuracy: 0.9944 - val_loss: 0.6613 - val_accuracy: 0.9098
# Epoch 138/150
# 5/5 [==============================] - ETA: 0s - loss: 0.2492 - accuracy: 0.9906
# Epoch 138: val_accuracy did not improve from 0.95489
# 5/5 [==============================] - 3s 512ms/step - loss: 0.2492 - accuracy: 0.9906 - val_loss: 0.7450 - val_accuracy: 0.8722
# Epoch 139/150
# 5/5 [==============================] - 3s 517ms/step - loss: 0.2500 - accuracy: 0.9944 - val_loss: 0.6553 - val_accuracy: 0.8872
# Epoch 140/150
# 5/5 [==============================] - ETA: 0s - loss: 0.2349 - accuracy: 0.9981
# Epoch 140: val_accuracy did not improve from 0.95489
# 5/5 [==============================] - 3s 489ms/step - loss: 0.2349 - accuracy: 0.9981 - val_loss: 0.6753 - val_accuracy: 0.9023
# Epoch 141/150
# 5/5 [==============================] - 3s 506ms/step - loss: 0.2326 - accuracy: 0.9981 - val_loss: 0.6320 - val_accuracy: 0.9173
# Epoch 142/150
# 5/5 [==============================] - ETA: 0s - loss: 0.2213 - accuracy: 1.0000
# Epoch 142: val_accuracy did not improve from 0.95489
# 5/5 [==============================] - 3s 508ms/step - loss: 0.2213 - accuracy: 1.0000 - val_loss: 0.6041 - val_accuracy: 0.9098
# Epoch 143/150
# 5/5 [==============================] - 3s 507ms/step - loss: 0.2133 - accuracy: 0.9981 - val_loss: 0.6981 - val_accuracy: 0.9023
# Epoch 144/150
# 5/5 [==============================] - ETA: 0s - loss: 0.2119 - accuracy: 0.9962
# Epoch 144: val_accuracy did not improve from 0.95489
# 5/5 [==============================] - 3s 508ms/step - loss: 0.2119 - accuracy: 0.9962 - val_loss: 0.7861 - val_accuracy: 0.8722
# Epoch 145/150
# 5/5 [==============================] - 3s 525ms/step - loss: 0.2066 - accuracy: 0.9944 - val_loss: 0.6539 - val_accuracy: 0.9023
# Epoch 146/150
# 5/5 [==============================] - ETA: 0s - loss: 0.1943 - accuracy: 0.9962
# Epoch 146: val_accuracy did not improve from 0.95489
# 5/5 [==============================] - 2s 483ms/step - loss: 0.1943 - accuracy: 0.9962 - val_loss: 0.5899 - val_accuracy: 0.8947
# Epoch 147/150
# 5/5 [==============================] - 2s 482ms/step - loss: 0.1866 - accuracy: 1.0000 - val_loss: 0.5808 - val_accuracy: 0.9023
# Epoch 148/150
# 5/5 [==============================] - ETA: 0s - loss: 0.1883 - accuracy: 0.9981
# Epoch 148: val_accuracy did not improve from 0.95489
# 5/5 [==============================] - 3s 508ms/step - loss: 0.1883 - accuracy: 0.9981 - val_loss: 0.5725 - val_accuracy: 0.9248
# Epoch 149/150
# 5/5 [==============================] - 2s 478ms/step - loss: 0.1754 - accuracy: 1.0000 - val_loss: 0.6095 - val_accuracy: 0.9098
# Epoch 150/150
# 5/5 [==============================] - ETA: 0s - loss: 0.1799 - accuracy: 0.9962
# Epoch 150: val_accuracy did not improve from 0.95489
# 5/5 [==============================] - 2s 488ms/step - loss: 0.1799 - accuracy: 0.9962 - val_loss: 0.4994 - val_accuracy: 0.9098
# 5/5 [==============================] - 0s 30ms/step - loss: 0.5900 - accuracy: 0.9549
# The loss is: 0.5900276899337769, and the accuracy is: 0.9548872113227844

# %% [markdown]
# ### First performance measurement

# %%
plt.plot(firstTraining.history['accuracy'])
plt.plot(firstTraining.history['val_accuracy'])
plt.title("Accuracy graph")
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.plot(firstTraining.history['loss'])
plt.plot(firstTraining.history['val_loss'])
plt.title("Loss graph")
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
y_pred = gonodactylus_simithii.predict(x_test)
result = confusion_matrix(y_test, y_pred.argmax(axis=1))
disp = ConfusionMatrixDisplay(result)
disp.plot()
plt.show()
# Out:
# 5/5 [==============================] - 0s 48ms/step

# %%
resultCR = metrics.classification_report(y_test.ravel(), y_pred.argmax(axis=1))
print("Classification Report:",)
print (resultCR)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91        27
#            1       1.00      0.93      0.96        27
#            2       1.00      0.92      0.96        26
#            3       0.96      0.96      0.96        26
#            4       0.96      1.00      0.98        27
#
#     accuracy                           0.95       133
#    macro avg       0.96      0.95      0.96       133
# weighted avg       0.96      0.95      0.96       133

# %%
report = metrics.classification_report(y_test.ravel(), y_pred.argmax(axis=1), output_dict=True)

f1_score = [report[str(i)]['f1-score'] for i in range(5)]

fig, ax = plt.subplots()
ax.bar(range(5), f1_score)
ax.set_xticks(range(5))
ax.set_xticklabels(['Empezar', 'Girar', 'Leprechaun', 'Mas', 'Menos'])
ax.set_ylabel('F1-score')
ax.set_title('F1-score graphic')
plt.show()

# %%
y_test_binario = to_categorical(y_test)

# Calcula la curva ROC para cada clase
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(5):
    fpr[i], tpr[i], _ = roc_curve(y_test_binario[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Calcula la curva ROC micro
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_binario.ravel(), y_pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Grafica la curva ROC
plt.figure()
lw = 2
plt.plot(fpr["micro"], tpr["micro"], color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc["micro"])
for i in range(5):
    plt.plot(fpr[i], tpr[i], lw=lw,
             label="ROC curve of class {}".format(i))

plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic - ROC')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### Save model

# %%
tf.keras.saving.save_model(
    gonodactylus_simithii, 'Nika.h5', overwrite=True, save_format='h5')

# %%
new_Model = MK.load_model('Nika.h5')
new_Model.summary()
# Out:
# Model: "model_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_13 (InputLayer)       [(None, 369, 496, 3)]     0
#
#  conv2d_120 (Conv2D)         (None, 369, 496, 8)       224
#
#  conv2d_121 (Conv2D)         (None, 369, 496, 8)       584
#
#  max_pooling2d_60 (MaxPoolin  (None, 184, 248, 8)      0
#  g2D)
#
#  conv2d_122 (Conv2D)         (None, 184, 248, 16)      1168
#
#  conv2d_123 (Conv2D)         (None, 184, 248, 16)      2320
#
#  max_pooling2d_61 (MaxPoolin  (None, 92, 124, 16)      0
#  g2D)
#
#  conv2d_124 (Conv2D)         (None, 92, 124, 32)       4640
#
#  conv2d_125 (Conv2D)         (None, 92, 124, 32)       9248
#
#  max_pooling2d_62 (MaxPoolin  (None, 46, 62, 32)       0
#  g2D)
#
#  conv2d_126 (Conv2D)         (None, 46, 62, 64)        18496
#
#  conv2d_127 (Conv2D)         (None, 46, 62, 64)        36928
#
#  max_pooling2d_63 (MaxPoolin  (None, 23, 31, 64)       0
#  g2D)
#
#  conv2d_128 (Conv2D)         (None, 23, 31, 128)       73856
#
#  conv2d_129 (Conv2D)         (None, 23, 31, 128)       147584
#
#  max_pooling2d_64 (MaxPoolin  (None, 11, 15, 128)      0
#  g2D)
#
#  flatten_12 (Flatten)        (None, 21120)             0
#
#  dense_48 (Dense)            (None, 512)               10813952
#
#  dropout_36 (Dropout)        (None, 512)               0
#
#  dense_49 (Dense)            (None, 512)               262656
#
#  dropout_37 (Dropout)        (None, 512)               0
#
#  dense_50 (Dense)            (None, 512)               262656
#
#  dropout_38 (Dropout)        (None, 512)               0
#
#  dense_51 (Dense)            (None, 5)                 2565
#
# =================================================================
# Total params: 11,636,877
# Trainable params: 11,636,877
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Testing the model
#
# ---

# %% [markdown]
# ## Cargar un audio de testeo y procesarlo

# %%
def testAudio(signal):

    trimmed_signal = librosa.effects.trim(signal, top_db= 20)
    reduced_noise_signal = nr.reduce_noise(trimmed_signal[0], fs)
    normalized_signal = librosa.util.normalize(reduced_noise_signal)

    fig, ax = plt.subplots()
    spectrum, frequs, t, im = ax.specgram(x=normalized_signal, Fs=fs, Fc=0, NFFT=n_fft_parameter, cmap=plt.cm.jet, scale='dB')
    ax.axis('off')
    buf = io.BytesIO()
    fig.savefig(buf, format='jpg', bbox_inches='tight', pad_inches=0, transparent=True)
    buf.seek(0)
    img = Image.open(buf)
    plt.close()

    box = (80, 58, 576, 427)
    img_crop = img.crop(box)
    img_array = np.asarray(img)

    plt.imshow(img_array, cmap='gray')
    plt.axis('off')
    plt.show()
    return img_array

# %% [markdown]
# ## Testing the model with new audios

# %%
# ["Empezar" == 0, "Girar" == 1, "Leprechaun" == 2, "Mas" == 3, "Menos" == 4]
RECORD = """
const sleep = time => new Promise(resolve => setTimeout(resolve, time))
const b2text = blob => new Promise(resolve => {
  const reader = new FileReader()
  reader.onloadend = e => resolve(e.srcElement.result)
  reader.readAsDataURL(blob)
})
var record = time => new Promise(async resolve => {
  stream = await navigator.mediaDevices.getUserMedia({ audio: {sampleSize: 16, channelCount: 1, sampleRate: 16000  }})
  recorder = new MediaRecorder(stream)
  chunks = []
  recorder.ondataavailable = e => chunks.push(e.data)
  recorder.start()
  await sleep(time)
  recorder.onstop = async ()=>{
    blob = new Blob(chunks)
    text = await b2text(blob)
    resolve(text)
  }
  recorder.stop()
})
"""

def record(sec, filename='audio.wav'):
  display(Javascript(RECORD))
  s = output.eval_js('record(%d)' % (sec * 1000))
  b = b64decode(s.split(',')[1])
  with open(filename, 'wb+') as f:
    f.write(b)

warnings.filterwarnings(action='ignore', category=FutureWarning)
warnings.filterwarnings(action='ignore', category=UserWarning)

print(f"Hable máximo 2 segundos")
record(2,'audio.wav')
# Out:
# Hable máximo 2 segundos

# %%
# Read the audio file
audio_file = 'audio.wav'
audio_data = open(audio_file, 'rb').read()

# Play the audio
Audio(audio_data)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Predict the new audio

# %%
# ["Empezar" == 0, "Girar" == 1, "Leprechaun" == 2, "Mas" == 3, "Menos" == 4]
rawAudioNew, s = librosa.load(path='audio.wav', sr=fs, mono=True)
test_signals_new = testAudio(rawAudioNew)
test_signals_new = np.reshape(test_signals_new,(1, 369, 496, 3))
prediction_new = new_Model.predict(test_signals_new).argmax(axis=1)
print(prediction_new)
predictionValueNew = new_Model.predict(test_signals_new)
print(predictionValueNew)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# [4]
# 1/1 [==============================] - 0s 28ms/step
# [[2.6869458e-07 2.7972010e-06 1.3784683e-06 7.9863057e-05 9.9991572e-01]]
